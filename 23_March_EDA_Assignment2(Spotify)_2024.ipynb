# %% [markdown]
# # <b><font color ='orange'>1.Dataset Link : </font></b><a href = "https://drive.google.com/file/d/12ahZWW-rJXSsV1SbPV_pWRK0DukpXv_9/view?usp=sharing">click here</a>

# %% [markdown]
# # <b><font color ='orange'>2.Dataset Link : </font></b><a href = "https://www.kaggle.com/datasets/akiboy96/spotify-dataset">click here</a>

# %% [markdown]
# # <b><font color = 'orange'> The spotify dataset
# ## <b><font color = 'blue'> Description
# - <b> The dataset titled "Spotify Data: Popular Hip hop Artists and Tracks" provides a curated collection of approximately 500 entries showcasing the vibrant realm of hip hop music. These entries meticulously compile the most celebrated hip hop tracks and artists, reflecting their significant influence on the genre's landscape. Each entry not only highlights the popularity and musical composition of the tracks but also underscores the creative prowess of the artists and their profound impact on global listeners.

# %% [markdown]
# ### <b><font color = 'blue'> Application in data science :
# - <b> The Spotify dataset on popular hip hop artists and tracks provides a valuable resource for numerous data science applications. Analysts can utilize this dataset to perform trend analysis, enabling them to discern the evolving popularity dynamics of top hip hop tracks over recent years. Additionally, the dataset facilitates network analysis, which can uncover collaborative patterns among top artists, shedding light on the genre's evolving collaborative landscape. Furthermore, data scientists can utilize this dataset for developing predictive models aimed at forecasting track popularity based on diverse features, offering valuable insights for artists, producers, and marketers.

# %% [markdown]
# # <b><font color = 'orange'> Features :
# - <b> `Artist` : The name of the artist, providing direct attribution to the creative mind behind the track.
# - <b> `Track Name` : The title of the track, encapsulating its identity and essence.
# - <b> `Popularity` : A numeric score reflecting the track's reception and appeal among Spotify listeners.
# - <b> `Duration (ms)` : The track's length in milliseconds, detailing the temporal extent of the musical experience.
# - <b> `Track ID` : A unique identifier within Spotify's ecosystem, enabling direct access to the track for further exploration.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set_theme()

# %%
df = pd.read_csv(r'C:\Users\HP\Dropbox\PC\Downloads\spotify.csv') # loading the dataset from local system

# %%
df
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 435  French Montana                                    Splash Brothers
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
# 439       Rick Ross                                       Stay Schemin
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...

# %%
df.head()
# Out:
#   Artist                               Track Name  Popularity  Duration (ms)  \
# 0  Drake  Rich Baby Daddy (feat. Sexyy Red & SZA)          92         319191
# 1  Drake                                One Dance          91         173986
# 2  Drake                       IDGAF (feat. Yeat)          90         260111
# 3  Drake     First Person Shooter (feat. J. Cole)          88         247444
# 4  Drake            Jimmy Cooks (feat. 21 Savage)          88         218364
#
#                  Track ID
# 0  1yeB8MUNeLo9Ek1UEpsyz6
# 1  1zi7xx7UVEFkmKfv06H8x0
# 2  2YSzYUF3jWqb9YP9VXmpjE
# 3  7aqfrAY2p9BUSiupwk3svU
# 4  3F5CgOj3wFlRv51JsHbxhe

# %%
df.shape
# Out:
# (440, 5)

# %%
df.dtypes
# Out:
# Artist           object
# Track Name       object
# Popularity        int64
# Duration (ms)     int64
# Track ID         object
# dtype: object

# %%
df.describe()
# Out:
#        Popularity  Duration (ms)
# count  440.000000     440.000000
# mean    75.736364  206810.040909
# std      9.886534   53576.930289
# min     29.000000   81666.000000
# 25%     70.000000  172778.500000
# 50%     77.000000  201866.000000
# 75%     83.000000  235119.750000
# max     97.000000  501648.000000

# %%
df.astype('O').describe()
# Out:
#        Artist                                         Track Name  Popularity  \
# count     440                                                440         440
# unique    115                                                412          51
# top     Drake  Annihilate (Spider-Man: Across the Spider-Vers...          79
# freq       20                                                  3          23
#
#         Duration (ms)                Track ID
# count             440                     440
# unique            410                     413
# top            231746  39MK3d3fonIP8Mz9oHCTBB
# freq                3                       3

# %%
# Let's check if there is a null value present or not
df.isnull().sum()
# Out:
# Artist           0
# Track Name       0
# Popularity       0
# Duration (ms)    0
# Track ID         0
# dtype: int64

# %% [markdown]
# ### <b> Obervation :
# <b> - There is no any null values present

# %%
# Let's check if there is a duplicate value present or not
df.duplicated().sum()
# Out:
# 27

# %% [markdown]
# ### <b> Obervation :
# - <b> There are 27 duplicate values present

# %%
# Let's Drop the duplicate values
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Artist', 'Track Name', 'Popularity', 'Duration (ms)', 'Track ID'], dtype='object')

# %% [markdown]
# # <b><font color = 'orange'>1. Identify the top 5 popular artists based on the mean popularity of their tracks. Show the mean popularity of tracks for the top 5 popular artists using BarPlot.

# %%
#First, calculate the mean popularity of tracks for each artist
mean_popularity_by_artist = df.groupby('Artist')['Popularity'].mean().sort_values(ascending=False)

#Select the top 5 popular artists based on the mean popularity
top_5_popular_artists = mean_popularity_by_artist.head(5)

# Plot the mean popularity of tracks for the top 5 popular artists using a BarPlot
plt.figure(figsize=(10, 6))
top_5_popular_artists.plot(kind='bar', color='skyblue')
plt.title('Mean Popularity of Tracks for Top 5 Popular Artists' , fontdict={'color':'blue','family':'arial','size':20})
plt.xlabel('Artist',fontdict={'color':'black','family':'arial','size':15,'fontweight':'bold'})
plt.ylabel('Mean Popularity',fontdict={'color':'black','family':'arial','size':15,'fontweight':'bold'})
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# # <b><font color = 'orange'>2. Determine the top 5 popular songs based on their popularity ratings. Display the popularity ratings of the top 5 popular songs using BarPlot.

# %%
top_5_popular_songs = df.loc[df['Popularity'] >= 90,['Track Name','Popularity']].sort_values(by = 'Popularity' , ascending = False)[:5]

# %%
top_5_popular_songs
# Out:
#                                   Track Name  Popularity
# 40                               Lovin On Me          97
# 70                                    redrum          96
# 260                                 CARNIVAL          96
# 30                FE!N (feat. Playboi Carti)          93
# 0    Rich Baby Daddy (feat. Sexyy Red & SZA)          92

# %%
df.nlargest(5, 'Popularity')
# Out:
#            Artist                               Track Name  Popularity  \
# 40    Jack Harlow                              Lovin On Me          97
# 70      21 Savage                                   redrum          96
# 260            ¥$                                 CARNIVAL          96
# 30   Travis Scott               FE!N (feat. Playboi Carti)          93
# 0           Drake  Rich Baby Daddy (feat. Sexyy Red & SZA)          92
#
#      Duration (ms)                Track ID
# 40          138411  4xhsWYTOGcal8zt0J161CU
# 70          270697  52eIcoLUM25zbQupAZYoFh
# 260         264324  3w0w2T288dec0mgeZZqoNN
# 30          191700  42VsgItocQwOQC3XWZ8JNA
# 0           319191  1yeB8MUNeLo9Ek1UEpsyz6

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data = top_5_popular_songs , x = top_5_popular_songs['Track Name'] , y = top_5_popular_songs['Popularity'] , palette='rainbow')
plt.title('top 5 popular songs based on their popularity ratings' , fontdict={'color':'blue','family':'arial','size':20})
plt.xlabel('Track Name',fontdict={'color':'black','family':'arial','size':15,'fontweight':'bold'})
plt.ylabel('Popularity',fontdict={'color':'black','family':'arial','size':15,'fontweight':'bold'})
plt.xticks(rotation = 45 , color = 'r')
plt.show()

# %% [markdown]
# # <b><font color = 'orange'>3. Find the top 5 trending genres based on the mean popularity of tracks within each genre. Visualize the mean popularity of tracks for the top 5 trending genres.

# %%
# Calculate the mean popularity of tracks for each genre
genre_mean_popularity = df.groupby('Track Name')['Popularity'].mean().sort_values(ascending=False)

# Identify the top 5 trending genres
top_trending_genres = genre_mean_popularity.nlargest(5)

# Create a bar plot to visualize the mean popularity of tracks for the top 5 trending genres
plt.figure(figsize=(12, 6))
top_trending_genres.plot(kind='bar', color='skyblue')
plt.title('Top 5 Trending Genres Based on Mean Popularity of Tracks',fontdict={'color':'blue','family':'arial','size':20})
plt.ylabel('Mean Popularity of Tracks',fontdict={'color':'black','family':'arial','size':15,'fontweight':'bold'})
plt.xlabel('Genre',fontdict={'color':'black','family':'arial','size':15,'fontweight':'bold'})
plt.xticks(rotation=45 , ticks=[0,1,2,3,4] , labels=['hip_hop','pop','rock','soul','jazz'] , color = 'r')
plt.tight_layout()
plt.show()

# %% [markdown]
# # <b><font color = 'orange'>4. Identify the top 5 longest songs among the tracks of the top 5 popular artists. Represent the duration of the top 5 longest songs among the tracks of the top 5 popular artists using BarPlot.

# %%
# Identify the top 5 popular artists based on the mean popularity of their tracks
top_popular_artists = df.groupby('Artist')['Popularity'].mean().nlargest(5).index.tolist()

# Extract the tracks of the top 5 popular artists
top_tracks = df[df['Artist'].isin(top_popular_artists)]

# Calculate the duration of each track and identify the top 5 longest songs
top_tracks['Duration'] =   df['Duration (ms)'].apply(lambda data : data//1000)# Convert duration in ms to duration in s
top_5_longest_songs = top_tracks.nlargest(5, 'Duration')

# Create a bar plot to visualize the duration of the top 5 longest songs
plt.figure(figsize=(10, 6))
plt.bar(top_5_longest_songs['Track Name'], top_5_longest_songs['Duration'], color='lightcoral')
plt.xlabel('Track Name',fontdict={'color':'black','family':'arial','size':15,'fontweight':'bold'})
plt.ylabel('Duration (in seconds)',fontdict={'color':'black','family':'arial','size':15,'fontweight':'bold'})
plt.title('Top 5 Longest Songs Among the Tracks of the Top 5 Popular Artists',fontdict={'color':'blue','family':'arial','size':20})
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # <b><font color = 'orange'>5. Determine the top 5 most danceable songs based on their danceability scores. Illustrate the danceability scores of the top 5 most danceable songs using

# %%
df1 = pd.read_csv(r'C:\Users\HP\Dropbox\PC\Downloads\spotify_dataset.csv')

# %%
df1.shape
# Out:
# (41099, 20)

# %%
df.shape
# Out:
# (413, 5)

# %%
df['Danceability'] = df1['danceability'][:413]

# %%
df.head()
# Out:
#   Artist                               Track Name  Popularity  Duration (ms)  \
# 0  Drake  Rich Baby Daddy (feat. Sexyy Red & SZA)          92         319191
# 1  Drake                                One Dance          91         173986
# 2  Drake                       IDGAF (feat. Yeat)          90         260111
# 3  Drake     First Person Shooter (feat. J. Cole)          88         247444
# 4  Drake            Jimmy Cooks (feat. 21 Savage)          88         218364
#
#                  Track ID  Danceability
# 0  1yeB8MUNeLo9Ek1UEpsyz6         0.417
# 1  1zi7xx7UVEFkmKfv06H8x0         0.498
# 2  2YSzYUF3jWqb9YP9VXmpjE         0.657
# 3  7aqfrAY2p9BUSiupwk3svU         0.590
# 4  3F5CgOj3wFlRv51JsHbxhe         0.515

# %%
# Sort the dataset based on danceability scores to find the top 5 most danceable songs
top_5_danceable_songs = df.nlargest(5, 'Danceability')

# Extract the song names and danceability scores of the top 5 most danceable songs
song_names = top_5_danceable_songs['Track Name']
danceability_scores = top_5_danceable_songs['Danceability']

# Create a PieChart to illustrate the danceability scores of the top 5 most danceable songs
explodes = [0.1,0,0,0,0]
plt.figure(figsize=(8, 8))
plt.pie(danceability_scores, labels=song_names, autopct='%1.1f%%', startangle=140 , shadow = True ,explode = explodes)
plt.axis('equal')  # Equal aspect ratio ensures that the pie is drawn as a circle.

plt.title('Danceability Scores of Top 5 Most Danceable Songs',fontdict={'color':'blue','family':'arial','size':20,'fontweight':'bold'})
plt.show()
